# %%
from IPython.display import display
from IPython.display import display_pretty, display_html, display_jpeg, display_png, display_json, display_latex, display_svg
from IPython.display import Image

# %%
i=Image('../data/plots/tw_all_english.png')
i

# %%
i=Image('../data/plots/tw_discrimination_english.png')
#i=Image('../data/plots/tw_prevention_english.png')
#i=Image('../data/plots/tw_campaign_english.png')
#i=Image('../data/plots/tw_testing_english.png')

i

# %%
i=Image('../data/plots/tw_total_english.png')
i

# %%
from IPython.core.display import HTML
styles = open("../css/custom.css", "r").read()
HTML(styles)
# Out:
# <style>
# @import url(https://fonts.googleapis.com/css?family=Roboto+Slab:400,100);
# @import url(https://fonts.googleapis.com/css?family=Roboto+Mono:300);
#
# body{
#   font-family: "Helvetica", "Helvetica Neue", sans-serif;
# }
#
# #notebook {
#   font-size: 1.1em !important;
#   font-weight: 100;
# }
#
# a {
# 	color: #138331;
# }
#
# h1, h2, h3, h4, h5 {
#   font-family: "Roboto Slab", sans-serif;
#   font-weight: 100 !important;
# }
#
# .CodeMirror{
#   font-family: "Roboto Mono", monospace;
#   font-weight: 300;
# }
#
# div.prompt{
#   font-family: "Roboto Mono", monospace;
#   font-weight: 300;
# }
#
# </style>
